# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime
import calendar

# %%
data = pd.read_csv('/content/drive/MyDrive/projects/data_analysis_projects/uber trips analysis/Uber+Drives+-+.csv')
data.head()
# Out:
#       START_DATE*       END_DATE*  ... MILES*         PURPOSE*
# 0  1/1/2016 21:11  1/1/2016 21:17  ...    5.1   Meal/Entertain
# 1   1/2/2016 1:25   1/2/2016 1:37  ...    5.0              NaN
# 2  1/2/2016 20:25  1/2/2016 20:38  ...    4.8  Errand/Supplies
# 3  1/5/2016 17:31  1/5/2016 17:45  ...    4.7          Meeting
# 4  1/6/2016 14:42  1/6/2016 15:49  ...   63.7   Customer Visit
#
# [5 rows x 7 columns]

# %%
## check for missing values

# %%
data.isnull().any()
# Out:
# START_DATE*    False
# END_DATE*       True
# CATEGORY*       True
# START*          True
# STOP*           True
# MILES*         False
# PURPOSE*        True
# dtype: bool

# %%
data.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# START_DATE*    0
# END_DATE*      0
# CATEGORY*      0
# START*         0
# STOP*          0
# MILES*         0
# PURPOSE*       0
# dtype: int64

# %%
data.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
data['START_DATE*'] = pd.to_datetime(data['START_DATE*'], format='%m/%d/%Y %H:%M')
data['END_DATE*'] = pd.to_datetime(data['END_DATE*'], format='%m/%d/%Y %H:%M')

# %%
data.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*      datetime64[ns]
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# dtype: object

# %%
hour = []
day = []
dayofweek = []
month = []
weekday = []

for x in data['START_DATE*']:
  hour.append(x.hour)
  day.append(x.day)
  dayofweek.append(x.dayofweek)
  month.append(x.month)
  weekday.append(calendar.day_name[dayofweek[-1]])

data['HOUR'] = hour
data['DAY'] = day
data['DAY OF WEEK'] = dayofweek
data['MONTH'] = month
data['WEEKDAY'] = weekday

# %%
data.head()
# Out:
#           START_DATE*           END_DATE*  ... MONTH    WEEKDAY
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  ...     1     Friday
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  ...     1   Saturday
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  ...     1    Tuesday
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  ...     1  Wednesday
# 5 2016-01-06 17:15:00 2016-01-06 17:19:00  ...     1  Wednesday
#
# [5 rows x 12 columns]

# %% [markdown]
# ## Categories we have

# %%
data['CATEGORY*'].value_counts()
# Out:
# Business    647
# Personal      6
# Name: CATEGORY*, dtype: int64

# %%
sns.countplot(x='CATEGORY*', data=data)

# %% [markdown]
# ## How long do people travel with Uber?

# %%
data['MILES*'].plot.hist()

# %% [markdown]
# ## What hour do most people take UBER to their destination?

# %%
data['HOUR'].value_counts().plot(kind='bar', color='red', figsize=(10,5))
plt.xlabel('Hours')
plt.ylabel('Frequency')
plt.title('Number of trips vs hours')
# Out:
# Text(0.5, 1.0, 'Number of trips vs hours')

# %% [markdown]
# ## Check the purpose of trips

# %%
data['PURPOSE*'].value_counts().plot(kind='bar', figsize=(10,5), color='green')

# %% [markdown]
# ## Which day has the highest number of trips

# %%
data['WEEKDAY'].value_counts().plot(kind='bar', color='blue', figsize=(10,5))

# %% [markdown]
# ## What are the number of trips per each day?

# %%
data['DAY'].value_counts().plot(kind='bar', color='yellow', figsize=(10,5))

# %% [markdown]
# ## What are the trips in the month

# %%
data['MONTH'].value_counts().plot(kind='bar', color='purple', figsize=(10,5))

# %% [markdown]
# ## Where do people start boarding their trip from most?

# %%
data['START*'].value_counts().plot(kind='bar', color='orange', figsize=(25,10))
